# %%
# !pip install -q tensorflow

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
## Cloning the tensorflow models repository

import os

# %cd /content
repo_url = "https://github.com/tensorflow/models.git"
# !git clone {repo_url}
# !git pull
# Out:
# /content
# Cloning into 'models'...
# remote: Enumerating objects: 43409, done.
# remote: Total 43409 (delta 0), reused 0 (delta 0), pack-reused 43409
# Receiving objects: 100% (43409/43409), 550.10 MiB | 36.57 MiB/s, done.
# Resolving deltas: 100% (29525/29525), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
## Installing the dependencies for the object detection API and setting the path

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install -q tf_slim

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'
os.environ['PYTHONPATH'] += ':/content/models'

# !python object_detection/builders/model_builder_test.py
# Out:
# Selecting previously unselected package python-bs4.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.1_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.3_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#      |████████████████████████████████| 358kB 4.8MB/s
# /content/models/research

# %%
## Path of tensorflow train and test TF Records and label map pbtxt file

test_record_fname = '/content/drive/My Drive/tf_records/test.record'
train_record_fname = '/content/drive/My Drive/tf_records/train.record'
label_map_pbtxt_fname = '/content/drive/My Drive/tf_records/face-masks_label_map.pbtxt'

# %%
## Choosing a model and the no. of steps for training

# Number of training steps.
num_steps = 100000  # 200000

# Number of evaluation steps.
num_eval_steps = 50

MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 12
    },
    'faster_rcnn_inception_v2': {
        'model_name': 'faster_rcnn_inception_v2_coco_2018_01_28',
        'pipeline_file': 'faster_rcnn_inception_v2_coco.config',
        'batch_size': 1
    },
    'rfcn_resnet101': {
        'model_name': 'rfcn_resnet101_coco_2018_01_28',
        'pipeline_file': 'rfcn_resnet101_pets.config',
        'batch_size': 8
    }
}

# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'faster_rcnn_inception_v2'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %%
## Downloading the model

# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /content/models/research

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research/pretrained_model
# total 111M
# drwxr-xr-x  3 345018 5000 4.0K Feb  1  2018 .
# drwxr-xr-x 24 root   root 4.0K Sep  5 19:15 ..
# -rw-r--r--  1 345018 5000   77 Feb  1  2018 checkpoint
# -rw-r--r--  1 345018 5000  55M Feb  1  2018 frozen_inference_graph.pb
# -rw-r--r--  1 345018 5000  51M Feb  1  2018 model.ckpt.data-00000-of-00001
# -rw-r--r--  1 345018 5000  16K Feb  1  2018 model.ckpt.index
# -rw-r--r--  1 345018 5000 5.5M Feb  1  2018 model.ckpt.meta
# -rw-r--r--  1 345018 5000 3.2K Feb  1  2018 pipeline.config
# drwxr-xr-x  3 345018 5000 4.0K Feb  1  2018 saved_model

# %%
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/models/research/pretrained_model/model.ckpt'

# %%
## Choosing a pipeline file (read more about it)
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/samples/configs/', pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)

# %%
## Function to get number of classes from label_map.pbtxt

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
## Setting the value of few of the variables 

import re

num_classes = get_num_classes(label_map_pbtxt_fname)
with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:
    
    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(train.record)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(val.record)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    
    # Set image size as 600, 866
    #s = re.sub('min_dimension: [0-9]+', 'min_dimension: {}'.format(500), s)
    f.write(s)

# %%
# !cat {pipeline_fname}
# Out:
# # Faster R-CNN with Inception v2, configuration for MSCOCO Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
#
# model {
#   faster_rcnn {
#     num_classes: 3
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: 'faster_rcnn_inception_v2'
#       first_stage_features_stride: 16
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         scales: [0.25, 0.5, 1.0, 2.0]
#         aspect_ratios: [0.5, 1.0, 2.0]
#         height_stride: 16
#         width_stride: 16
#       }
#     }
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.01
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.7
#     first_stage_max_proposals: 300
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     initial_crop_size: 14
#     maxpool_kernel_size: 2
#     maxpool_stride: 2
#     second_stage_box_predictor {
#       mask_rcnn_box_predictor {
#         use_dropout: false
#         dropout_keep_probability: 1.0
#         fc_hyperparams {
#           op: FC
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             variance_scaling_initializer {
#               factor: 1.0
#               uniform: true
#               mode: FAN_AVG
#             }
#           }
#         }
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.0
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 300
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#   }
# }
#
# train_config: {
#   batch_size: 1
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         manual_step_learning_rate {
#           initial_learning_rate: 0.0002
#           schedule {
#             step: 900000
#             learning_rate: .00002
#           }
#           schedule {
#             step: 1200000
#             learning_rate: .000002
#           }
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   gradient_clipping_by_norm: 10.0
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/model.ckpt"
#   from_detection_checkpoint: true
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the COCO dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 100000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
# }
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/drive/My Drive/tf_records/train.record"
#   }
#   label_map_path: "/content/drive/My Drive/tf_records/face-masks_label_map.pbtxt"
# }
#
# eval_config: {
#   num_examples: 8000
#   # Note: The below line limits the evaluation process to 10 evaluations.
#   # Remove the below line to evaluate indefinitely.
#   max_evals: 10
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/drive/My Drive/tf_records/test.record"
#   }
#   label_map_path: "/content/drive/My Drive/tf_records/face-masks_label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %%
model_dir = 'training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# Setting up Tensorboard for visualising how the model is getting trained

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2020-09-04 07:00:22--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.54.124.219, 18.213.76.145, 34.195.187.253, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.54.124.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  37.2MB/s    in 0.4s
#
# 2020-09-04 07:00:22 (37.2 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://724d0db179b0.ngrok.io

# %% [markdown]
# Training the model

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# Streaming output truncated to the last 5000 lines.
# 2020-09-04 10:51:19.791495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 10:51:19.791977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 10:51:19.792332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-04 10:51:19.792389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-04 10:51:19.792410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-04 10:51:19.792427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-04 10:51:19.792607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 10:51:19.793056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 10:51:19.793422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-42025
# I0904 10:51:19.794665 140579447977856 saver.py:1284] Restoring parameters from training/model.ckpt-42025
# INFO:tensorflow:Running local_init_op.
# I0904 10:51:20.932281 140579447977856 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0904 10:51:21.104624 140579447977856 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 103 images.
# I0904 10:51:41.033676 140576137803520 coco_evaluation.py:282] Performing evaluation on 103 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0904 10:51:41.034474 140576137803520 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0904 10:51:41.059438 140576137803520 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.08s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.315
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
# INFO:tensorflow:Finished evaluation at 2020-09-04-10:51:43
# I0904 10:51:43.579255 140579447977856 evaluation.py:275] Finished evaluation at 2020-09-04-10:51:43
# INFO:tensorflow:Saving dict for global step 42025: DetectionBoxes_Precision/mAP = 0.21250083, DetectionBoxes_Precision/mAP (large) = 0.6322354, DetectionBoxes_Precision/mAP (medium) = 0.3148696, DetectionBoxes_Precision/mAP (small) = 0.11658338, DetectionBoxes_Precision/mAP@.50IOU = 0.4667908, DetectionBoxes_Precision/mAP@.75IOU = 0.14375448, DetectionBoxes_Recall/AR@1 = 0.1932941, DetectionBoxes_Recall/AR@10 = 0.33282393, DetectionBoxes_Recall/AR@100 = 0.37820897, DetectionBoxes_Recall/AR@100 (large) = 0.6523529, DetectionBoxes_Recall/AR@100 (medium) = 0.49651417, DetectionBoxes_Recall/AR@100 (small) = 0.28259423, Loss/BoxClassifierLoss/classification_loss = 0.120463945, Loss/BoxClassifierLoss/localization_loss = 0.13133878, Loss/RPNLoss/localization_loss = 0.07957043, Loss/RPNLoss/objectness_loss = 0.06762261, Loss/total_loss = 0.39899585, global_step = 42025, learning_rate = 0.0002, loss = 0.39899585
# I0904 10:51:43.579703 140579447977856 estimator.py:2049] Saving dict for global step 42025: DetectionBoxes_Precision/mAP = 0.21250083, DetectionBoxes_Precision/mAP (large) = 0.6322354, DetectionBoxes_Precision/mAP (medium) = 0.3148696, DetectionBoxes_Precision/mAP (small) = 0.11658338, DetectionBoxes_Precision/mAP@.50IOU = 0.4667908, DetectionBoxes_Precision/mAP@.75IOU = 0.14375448, DetectionBoxes_Recall/AR@1 = 0.1932941, DetectionBoxes_Recall/AR@10 = 0.33282393, DetectionBoxes_Recall/AR@100 = 0.37820897, DetectionBoxes_Recall/AR@100 (large) = 0.6523529, DetectionBoxes_Recall/AR@100 (medium) = 0.49651417, DetectionBoxes_Recall/AR@100 (small) = 0.28259423, Loss/BoxClassifierLoss/classification_loss = 0.120463945, Loss/BoxClassifierLoss/localization_loss = 0.13133878, Loss/RPNLoss/localization_loss = 0.07957043, Loss/RPNLoss/objectness_loss = 0.06762261, Loss/total_loss = 0.39899585, global_step = 42025, learning_rate = 0.0002, loss = 0.39899585
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 42025: training/model.ckpt-42025
# I0904 10:51:43.583502 140579447977856 estimator.py:2109] Saving 'checkpoint_path' summary for global step 42025: training/model.ckpt-42025
# INFO:tensorflow:global_step/sec: 1.62627
# I0904 10:52:06.401442 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 1.62627
# INFO:tensorflow:loss = 0.45656815, step = 42100 (61.491 sec)
# I0904 10:52:06.402673 140579447977856 basic_session_run_hooks.py:260] loss = 0.45656815, step = 42100 (61.491 sec)
# INFO:tensorflow:global_step/sec: 3.30758
# I0904 10:52:36.635086 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.30758
# INFO:tensorflow:loss = 0.13154078, step = 42200 (30.234 sec)
# I0904 10:52:36.636260 140579447977856 basic_session_run_hooks.py:260] loss = 0.13154078, step = 42200 (30.234 sec)
# INFO:tensorflow:global_step/sec: 3.25818
# I0904 10:53:07.327007 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.25818
# INFO:tensorflow:loss = 0.17924386, step = 42300 (30.692 sec)
# I0904 10:53:07.328425 140579447977856 basic_session_run_hooks.py:260] loss = 0.17924386, step = 42300 (30.692 sec)
# INFO:tensorflow:global_step/sec: 3.26391
# I0904 10:53:37.965106 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.26391
# INFO:tensorflow:loss = 0.2033398, step = 42400 (30.638 sec)
# I0904 10:53:37.966509 140579447977856 basic_session_run_hooks.py:260] loss = 0.2033398, step = 42400 (30.638 sec)
# INFO:tensorflow:global_step/sec: 3.24872
# I0904 10:54:08.746519 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.24872
# INFO:tensorflow:loss = 0.59953403, step = 42500 (30.781 sec)
# I0904 10:54:08.747716 140579447977856 basic_session_run_hooks.py:260] loss = 0.59953403, step = 42500 (30.781 sec)
# 2020-09-04 10:54:25.997510: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:global_step/sec: 3.29507
# I0904 10:54:39.094817 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29507
# INFO:tensorflow:loss = 0.81806856, step = 42600 (30.348 sec)
# I0904 10:54:39.095930 140579447977856 basic_session_run_hooks.py:260] loss = 0.81806856, step = 42600 (30.348 sec)
# INFO:tensorflow:global_step/sec: 3.28105
# I0904 10:55:09.572967 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28105
# INFO:tensorflow:loss = 0.242023, step = 42700 (30.479 sec)
# I0904 10:55:09.574466 140579447977856 basic_session_run_hooks.py:260] loss = 0.242023, step = 42700 (30.479 sec)
# 2020-09-04 10:55:28.100332: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:global_step/sec: 3.28937
# I0904 10:55:39.973904 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28937
# INFO:tensorflow:loss = 1.3322567, step = 42800 (30.401 sec)
# I0904 10:55:39.975359 140579447977856 basic_session_run_hooks.py:260] loss = 1.3322567, step = 42800 (30.401 sec)
# INFO:tensorflow:global_step/sec: 3.29139
# I0904 10:56:10.356157 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29139
# INFO:tensorflow:loss = 0.32642108, step = 42900 (30.382 sec)
# I0904 10:56:10.357290 140579447977856 basic_session_run_hooks.py:260] loss = 0.32642108, step = 42900 (30.382 sec)
# INFO:tensorflow:global_step/sec: 3.30084
# I0904 10:56:40.651410 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.30084
# INFO:tensorflow:loss = 0.47016957, step = 43000 (30.296 sec)
# I0904 10:56:40.652915 140579447977856 basic_session_run_hooks.py:260] loss = 0.47016957, step = 43000 (30.296 sec)
# INFO:tensorflow:global_step/sec: 3.30596
# I0904 10:57:10.899775 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.30596
# INFO:tensorflow:loss = 0.5699304, step = 43100 (30.248 sec)
# I0904 10:57:10.901151 140579447977856 basic_session_run_hooks.py:260] loss = 0.5699304, step = 43100 (30.248 sec)
# INFO:tensorflow:global_step/sec: 3.2627
# I0904 10:57:41.549296 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.2627
# INFO:tensorflow:loss = 0.77670324, step = 43200 (30.649 sec)
# I0904 10:57:41.550631 140579447977856 basic_session_run_hooks.py:260] loss = 0.77670324, step = 43200 (30.649 sec)
# INFO:tensorflow:global_step/sec: 3.30187
# I0904 10:58:11.835181 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.30187
# INFO:tensorflow:loss = 0.94609463, step = 43300 (30.286 sec)
# I0904 10:58:11.836472 140579447977856 basic_session_run_hooks.py:260] loss = 0.94609463, step = 43300 (30.286 sec)
# INFO:tensorflow:global_step/sec: 3.29853
# I0904 10:58:42.151637 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29853
# INFO:tensorflow:loss = 0.29782483, step = 43400 (30.316 sec)
# I0904 10:58:42.152857 140579447977856 basic_session_run_hooks.py:260] loss = 0.29782483, step = 43400 (30.316 sec)
# 2020-09-04 10:58:56.283142: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:global_step/sec: 3.25595
# I0904 10:59:12.864625 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.25595
# INFO:tensorflow:loss = 1.0068249, step = 43500 (30.713 sec)
# I0904 10:59:12.865643 140579447977856 basic_session_run_hooks.py:260] loss = 1.0068249, step = 43500 (30.713 sec)
# INFO:tensorflow:global_step/sec: 3.24465
# I0904 10:59:43.684600 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.24465
# INFO:tensorflow:loss = 0.52536976, step = 43600 (30.820 sec)
# I0904 10:59:43.685832 140579447977856 basic_session_run_hooks.py:260] loss = 0.52536976, step = 43600 (30.820 sec)
# INFO:tensorflow:global_step/sec: 3.31584
# I0904 11:00:13.842844 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.31584
# INFO:tensorflow:loss = 0.45118776, step = 43700 (30.158 sec)
# I0904 11:00:13.843879 140579447977856 basic_session_run_hooks.py:260] loss = 0.45118776, step = 43700 (30.158 sec)
# INFO:tensorflow:global_step/sec: 3.282
# I0904 11:00:44.312089 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.282
# INFO:tensorflow:loss = 0.78774667, step = 43800 (30.470 sec)
# I0904 11:00:44.313665 140579447977856 basic_session_run_hooks.py:260] loss = 0.78774667, step = 43800 (30.470 sec)
# INFO:tensorflow:Saving checkpoints for 43892 into training/model.ckpt.
# I0904 11:01:12.114715 140579447977856 basic_session_run_hooks.py:606] Saving checkpoints for 43892 into training/model.ckpt.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fda68d4f4e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0904 11:01:13.192661 140579447977856 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fda68d4f4e0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda67cf72f0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0904 11:01:13.433946 140579447977856 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda67cf72f0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0904 11:01:14.120283 140579447977856 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:01:15.825999 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:01:16.004332 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0904 11:01:16.004826 140579447977856 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:01:17.251471 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:01:17.271864 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I0904 11:01:19.776685 140579447977856 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-04T11:01:19Z
# I0904 11:01:19.797922 140579447977856 evaluation.py:255] Starting evaluation at 2020-09-04T11:01:19Z
# INFO:tensorflow:Graph was finalized.
# I0904 11:01:20.394443 140579447977856 monitored_session.py:240] Graph was finalized.
# 2020-09-04 11:01:20.395306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:01:20.395951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-09-04 11:01:20.396081: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-04 11:01:20.396143: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-09-04 11:01:20.396205: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-09-04 11:01:20.396250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-09-04 11:01:20.396303: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-09-04 11:01:20.396345: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-09-04 11:01:20.396386: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-04 11:01:20.396530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:01:20.397006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:01:20.397377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-04 11:01:20.397434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-04 11:01:20.397455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-04 11:01:20.397471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-04 11:01:20.397682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:01:20.398149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:01:20.398515: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-43892
# I0904 11:01:20.399821 140579447977856 saver.py:1284] Restoring parameters from training/model.ckpt-43892
# INFO:tensorflow:Running local_init_op.
# I0904 11:01:21.638218 140579447977856 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0904 11:01:21.836555 140579447977856 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 103 images.
# I0904 11:01:42.172640 140576146196224 coco_evaluation.py:282] Performing evaluation on 103 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0904 11:01:42.173616 140576146196224 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I0904 11:01:42.200378 140576146196224 coco_tools.py:138] DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.14s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.227
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.490
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.153
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.313
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.687
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.360
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.733
# INFO:tensorflow:Finished evaluation at 2020-09-04-11:01:44
# I0904 11:01:44.783356 140579447977856 evaluation.py:275] Finished evaluation at 2020-09-04-11:01:44
# INFO:tensorflow:Saving dict for global step 43892: DetectionBoxes_Precision/mAP = 0.22682771, DetectionBoxes_Precision/mAP (large) = 0.68729657, DetectionBoxes_Precision/mAP (medium) = 0.31343752, DetectionBoxes_Precision/mAP (small) = 0.12727204, DetectionBoxes_Precision/mAP@.50IOU = 0.49012655, DetectionBoxes_Precision/mAP@.75IOU = 0.1528851, DetectionBoxes_Recall/AR@1 = 0.22616847, DetectionBoxes_Recall/AR@10 = 0.35951418, DetectionBoxes_Recall/AR@100 = 0.3935966, DetectionBoxes_Recall/AR@100 (large) = 0.7327451, DetectionBoxes_Recall/AR@100 (medium) = 0.4909586, DetectionBoxes_Recall/AR@100 (small) = 0.2957933, Loss/BoxClassifierLoss/classification_loss = 0.1221913, Loss/BoxClassifierLoss/localization_loss = 0.1262605, Loss/RPNLoss/localization_loss = 0.07817857, Loss/RPNLoss/objectness_loss = 0.06268003, Loss/total_loss = 0.3893105, global_step = 43892, learning_rate = 0.0002, loss = 0.3893105
# I0904 11:01:44.783724 140579447977856 estimator.py:2049] Saving dict for global step 43892: DetectionBoxes_Precision/mAP = 0.22682771, DetectionBoxes_Precision/mAP (large) = 0.68729657, DetectionBoxes_Precision/mAP (medium) = 0.31343752, DetectionBoxes_Precision/mAP (small) = 0.12727204, DetectionBoxes_Precision/mAP@.50IOU = 0.49012655, DetectionBoxes_Precision/mAP@.75IOU = 0.1528851, DetectionBoxes_Recall/AR@1 = 0.22616847, DetectionBoxes_Recall/AR@10 = 0.35951418, DetectionBoxes_Recall/AR@100 = 0.3935966, DetectionBoxes_Recall/AR@100 (large) = 0.7327451, DetectionBoxes_Recall/AR@100 (medium) = 0.4909586, DetectionBoxes_Recall/AR@100 (small) = 0.2957933, Loss/BoxClassifierLoss/classification_loss = 0.1221913, Loss/BoxClassifierLoss/localization_loss = 0.1262605, Loss/RPNLoss/localization_loss = 0.07817857, Loss/RPNLoss/objectness_loss = 0.06268003, Loss/total_loss = 0.3893105, global_step = 43892, learning_rate = 0.0002, loss = 0.3893105
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43892: training/model.ckpt-43892
# I0904 11:01:44.787108 140579447977856 estimator.py:2109] Saving 'checkpoint_path' summary for global step 43892: training/model.ckpt-43892
# INFO:tensorflow:global_step/sec: 1.58089
# I0904 11:01:47.567692 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 1.58089
# INFO:tensorflow:loss = 0.59728444, step = 43900 (63.255 sec)
# I0904 11:01:47.568722 140579447977856 basic_session_run_hooks.py:260] loss = 0.59728444, step = 43900 (63.255 sec)
# INFO:tensorflow:global_step/sec: 3.31485
# I0904 11:02:17.734997 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.31485
# INFO:tensorflow:loss = 0.98110735, step = 44000 (30.168 sec)
# I0904 11:02:17.736293 140579447977856 basic_session_run_hooks.py:260] loss = 0.98110735, step = 44000 (30.168 sec)
# INFO:tensorflow:global_step/sec: 3.2818
# I0904 11:02:48.206042 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.2818
# INFO:tensorflow:loss = 0.5925172, step = 44100 (30.471 sec)
# I0904 11:02:48.207221 140579447977856 basic_session_run_hooks.py:260] loss = 0.5925172, step = 44100 (30.471 sec)
# 2020-09-04 11:03:01.997304: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:global_step/sec: 3.3034
# I0904 11:03:18.477848 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.3034
# INFO:tensorflow:loss = 0.3039548, step = 44200 (30.272 sec)
# I0904 11:03:18.479145 140579447977856 basic_session_run_hooks.py:260] loss = 0.3039548, step = 44200 (30.272 sec)
# INFO:tensorflow:global_step/sec: 3.32617
# I0904 11:03:48.542509 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.32617
# INFO:tensorflow:loss = 0.26778626, step = 44300 (30.065 sec)
# I0904 11:03:48.543705 140579447977856 basic_session_run_hooks.py:260] loss = 0.26778626, step = 44300 (30.065 sec)
# INFO:tensorflow:global_step/sec: 3.28855
# I0904 11:04:18.951005 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28855
# INFO:tensorflow:loss = 1.216889, step = 44400 (30.408 sec)
# I0904 11:04:18.952158 140579447977856 basic_session_run_hooks.py:260] loss = 1.216889, step = 44400 (30.408 sec)
# INFO:tensorflow:global_step/sec: 3.27822
# I0904 11:04:49.455375 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.27822
# INFO:tensorflow:loss = 5.732002, step = 44500 (30.504 sec)
# I0904 11:04:49.456574 140579447977856 basic_session_run_hooks.py:260] loss = 5.732002, step = 44500 (30.504 sec)
# INFO:tensorflow:global_step/sec: 3.28719
# I0904 11:05:19.876506 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28719
# INFO:tensorflow:loss = 1.1700943, step = 44600 (30.421 sec)
# I0904 11:05:19.877977 140579447977856 basic_session_run_hooks.py:260] loss = 1.1700943, step = 44600 (30.421 sec)
# INFO:tensorflow:global_step/sec: 3.28763
# I0904 11:05:50.293609 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28763
# INFO:tensorflow:loss = 0.17183478, step = 44700 (30.417 sec)
# I0904 11:05:50.294893 140579447977856 basic_session_run_hooks.py:260] loss = 0.17183478, step = 44700 (30.417 sec)
# 2020-09-04 11:06:12.887496: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:global_step/sec: 3.26707
# I0904 11:06:20.902025 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.26707
# INFO:tensorflow:loss = 0.4234147, step = 44800 (30.608 sec)
# I0904 11:06:20.903289 140579447977856 basic_session_run_hooks.py:260] loss = 0.4234147, step = 44800 (30.608 sec)
# INFO:tensorflow:global_step/sec: 3.28327
# I0904 11:06:51.359507 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28327
# INFO:tensorflow:loss = 0.22844504, step = 44900 (30.458 sec)
# I0904 11:06:51.360832 140579447977856 basic_session_run_hooks.py:260] loss = 0.22844504, step = 44900 (30.458 sec)
# INFO:tensorflow:global_step/sec: 3.27066
# I0904 11:07:21.934460 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.27066
# INFO:tensorflow:loss = 1.466879, step = 45000 (30.575 sec)
# I0904 11:07:21.935919 140579447977856 basic_session_run_hooks.py:260] loss = 1.466879, step = 45000 (30.575 sec)
# INFO:tensorflow:global_step/sec: 3.27673
# I0904 11:07:52.452696 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.27673
# INFO:tensorflow:loss = 0.92500967, step = 45100 (30.518 sec)
# I0904 11:07:52.454120 140579447977856 basic_session_run_hooks.py:260] loss = 0.92500967, step = 45100 (30.518 sec)
# INFO:tensorflow:global_step/sec: 3.29695
# I0904 11:08:22.783667 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29695
# INFO:tensorflow:loss = 0.272278, step = 45200 (30.331 sec)
# I0904 11:08:22.785065 140579447977856 basic_session_run_hooks.py:260] loss = 0.272278, step = 45200 (30.331 sec)
# INFO:tensorflow:global_step/sec: 3.28453
# I0904 11:08:53.229402 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28453
# INFO:tensorflow:loss = 0.16337971, step = 45300 (30.446 sec)
# I0904 11:08:53.230690 140579447977856 basic_session_run_hooks.py:260] loss = 0.16337971, step = 45300 (30.446 sec)
# INFO:tensorflow:global_step/sec: 3.28936
# I0904 11:09:23.630414 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28936
# INFO:tensorflow:loss = 0.21752885, step = 45400 (30.401 sec)
# I0904 11:09:23.631753 140579447977856 basic_session_run_hooks.py:260] loss = 0.21752885, step = 45400 (30.401 sec)
# INFO:tensorflow:global_step/sec: 3.2684
# I0904 11:09:54.226465 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.2684
# INFO:tensorflow:loss = 0.42522013, step = 45500 (30.596 sec)
# I0904 11:09:54.227944 140579447977856 basic_session_run_hooks.py:260] loss = 0.42522013, step = 45500 (30.596 sec)
# INFO:tensorflow:global_step/sec: 3.23556
# I0904 11:10:25.133007 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.23556
# INFO:tensorflow:loss = 0.17461571, step = 45600 (30.906 sec)
# I0904 11:10:25.134217 140579447977856 basic_session_run_hooks.py:260] loss = 0.17461571, step = 45600 (30.906 sec)
# INFO:tensorflow:global_step/sec: 3.28029
# I0904 11:10:55.618248 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28029
# INFO:tensorflow:loss = 0.50383675, step = 45700 (30.485 sec)
# I0904 11:10:55.619641 140579447977856 basic_session_run_hooks.py:260] loss = 0.50383675, step = 45700 (30.485 sec)
# INFO:tensorflow:Saving checkpoints for 45756 into training/model.ckpt.
# I0904 11:11:12.380741 140579447977856 basic_session_run_hooks.py:606] Saving checkpoints for 45756 into training/model.ckpt.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fda693c3da0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0904 11:11:13.494232 140579447977856 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fda693c3da0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda6927bb70> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0904 11:11:13.722645 140579447977856 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda6927bb70> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0904 11:11:14.436568 140579447977856 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:11:16.486033 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:11:16.671084 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0904 11:11:16.671746 140579447977856 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:11:17.943285 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:11:17.963940 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I0904 11:11:20.199862 140579447977856 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-04T11:11:20Z
# I0904 11:11:20.220376 140579447977856 evaluation.py:255] Starting evaluation at 2020-09-04T11:11:20Z
# INFO:tensorflow:Graph was finalized.
# I0904 11:11:20.801732 140579447977856 monitored_session.py:240] Graph was finalized.
# 2020-09-04 11:11:20.802734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:11:20.803205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-09-04 11:11:20.803307: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-04 11:11:20.803349: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-09-04 11:11:20.803392: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-09-04 11:11:20.803447: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-09-04 11:11:20.803504: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-09-04 11:11:20.803588: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-09-04 11:11:20.803638: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-04 11:11:20.803780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:11:20.804250: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:11:20.804737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-04 11:11:20.804811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-04 11:11:20.804862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-04 11:11:20.804877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-04 11:11:20.805072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:11:20.805566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 11:11:20.805931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-45756
# I0904 11:11:20.807229 140579447977856 saver.py:1284] Restoring parameters from training/model.ckpt-45756
# INFO:tensorflow:Running local_init_op.
# I0904 11:11:21.979875 140579447977856 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0904 11:11:22.163669 140579447977856 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 103 images.
# I0904 11:11:42.529142 140576137803520 coco_evaluation.py:282] Performing evaluation on 103 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0904 11:11:42.529927 140576137803520 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I0904 11:11:42.557920 140576137803520 coco_tools.py:138] DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.14s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.685
# INFO:tensorflow:Finished evaluation at 2020-09-04-11:11:45
# I0904 11:11:45.133345 140579447977856 evaluation.py:275] Finished evaluation at 2020-09-04-11:11:45
# INFO:tensorflow:Saving dict for global step 45756: DetectionBoxes_Precision/mAP = 0.1964031, DetectionBoxes_Precision/mAP (large) = 0.6672382, DetectionBoxes_Precision/mAP (medium) = 0.24960364, DetectionBoxes_Precision/mAP (small) = 0.11696626, DetectionBoxes_Precision/mAP@.50IOU = 0.41555056, DetectionBoxes_Precision/mAP@.75IOU = 0.17065553, DetectionBoxes_Recall/AR@1 = 0.19757757, DetectionBoxes_Recall/AR@10 = 0.3312324, DetectionBoxes_Recall/AR@100 = 0.36921585, DetectionBoxes_Recall/AR@100 (large) = 0.6854902, DetectionBoxes_Recall/AR@100 (medium) = 0.4566449, DetectionBoxes_Recall/AR@100 (small) = 0.2721052, Loss/BoxClassifierLoss/classification_loss = 0.10990177, Loss/BoxClassifierLoss/localization_loss = 0.11041581, Loss/RPNLoss/localization_loss = 0.07959609, Loss/RPNLoss/objectness_loss = 0.06668975, Loss/total_loss = 0.36660337, global_step = 45756, learning_rate = 0.0002, loss = 0.36660337
# I0904 11:11:45.133685 140579447977856 estimator.py:2049] Saving dict for global step 45756: DetectionBoxes_Precision/mAP = 0.1964031, DetectionBoxes_Precision/mAP (large) = 0.6672382, DetectionBoxes_Precision/mAP (medium) = 0.24960364, DetectionBoxes_Precision/mAP (small) = 0.11696626, DetectionBoxes_Precision/mAP@.50IOU = 0.41555056, DetectionBoxes_Precision/mAP@.75IOU = 0.17065553, DetectionBoxes_Recall/AR@1 = 0.19757757, DetectionBoxes_Recall/AR@10 = 0.3312324, DetectionBoxes_Recall/AR@100 = 0.36921585, DetectionBoxes_Recall/AR@100 (large) = 0.6854902, DetectionBoxes_Recall/AR@100 (medium) = 0.4566449, DetectionBoxes_Recall/AR@100 (small) = 0.2721052, Loss/BoxClassifierLoss/classification_loss = 0.10990177, Loss/BoxClassifierLoss/localization_loss = 0.11041581, Loss/RPNLoss/localization_loss = 0.07959609, Loss/RPNLoss/objectness_loss = 0.06668975, Loss/total_loss = 0.36660337, global_step = 45756, learning_rate = 0.0002, loss = 0.36660337
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45756: training/model.ckpt-45756
# I0904 11:11:45.137037 140579447977856 estimator.py:2109] Saving 'checkpoint_path' summary for global step 45756: training/model.ckpt-45756
# INFO:tensorflow:global_step/sec: 1.58511
# I0904 11:11:58.705297 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 1.58511
# INFO:tensorflow:loss = 0.18223846, step = 45800 (63.088 sec)
# I0904 11:11:58.707175 140579447977856 basic_session_run_hooks.py:260] loss = 0.18223846, step = 45800 (63.088 sec)
# INFO:tensorflow:global_step/sec: 3.24794
# I0904 11:12:29.493980 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.24794
# INFO:tensorflow:loss = 0.3246587, step = 45900 (30.788 sec)
# I0904 11:12:29.495436 140579447977856 basic_session_run_hooks.py:260] loss = 0.3246587, step = 45900 (30.788 sec)
# INFO:tensorflow:global_step/sec: 3.24283
# I0904 11:13:00.331155 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.24283
# INFO:tensorflow:loss = 0.2848345, step = 46000 (30.837 sec)
# I0904 11:13:00.332524 140579447977856 basic_session_run_hooks.py:260] loss = 0.2848345, step = 46000 (30.837 sec)
# INFO:tensorflow:global_step/sec: 3.25687
# I0904 11:13:31.035483 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.25687
# INFO:tensorflow:loss = 0.39315972, step = 46100 (30.704 sec)
# I0904 11:13:31.036890 140579447977856 basic_session_run_hooks.py:260] loss = 0.39315972, step = 46100 (30.704 sec)
# INFO:tensorflow:global_step/sec: 3.31026
# I0904 11:14:01.244592 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.31026
# INFO:tensorflow:loss = 0.6691077, step = 46200 (30.209 sec)
# I0904 11:14:01.245873 140579447977856 basic_session_run_hooks.py:260] loss = 0.6691077, step = 46200 (30.209 sec)
# INFO:tensorflow:global_step/sec: 3.31304
# I0904 11:14:31.428363 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.31304
# INFO:tensorflow:loss = 0.89509356, step = 46300 (30.184 sec)
# I0904 11:14:31.429744 140579447977856 basic_session_run_hooks.py:260] loss = 0.89509356, step = 46300 (30.184 sec)
# INFO:tensorflow:global_step/sec: 3.2762
# I0904 11:15:01.951453 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.2762
# INFO:tensorflow:loss = 0.25073254, step = 46400 (30.523 sec)
# I0904 11:15:01.952754 140579447977856 basic_session_run_hooks.py:260] loss = 0.25073254, step = 46400 (30.523 sec)
# INFO:tensorflow:global_step/sec: 3.29148
# I0904 11:15:32.332998 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29148
# INFO:tensorflow:loss = 1.028348, step = 46500 (30.382 sec)
# I0904 11:15:32.334320 140579447977856 basic_session_run_hooks.py:260] loss = 1.028348, step = 46500 (30.382 sec)
# INFO:tensorflow:global_step/sec: 3.25135
# I0904 11:16:03.089414 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.25135
# INFO:tensorflow:loss = 0.1345391, step = 46600 (30.756 sec)
# I0904 11:16:03.090683 140579447977856 basic_session_run_hooks.py:260] loss = 0.1345391, step = 46600 (30.756 sec)
# INFO:tensorflow:global_step/sec: 3.29796
# I0904 11:16:33.411204 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29796
# INFO:tensorflow:loss = 0.78218395, step = 46700 (30.322 sec)
# I0904 11:16:33.412412 140579447977856 basic_session_run_hooks.py:260] loss = 0.78218395, step = 46700 (30.322 sec)
# INFO:tensorflow:global_step/sec: 3.26654
# I0904 11:17:04.024684 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.26654
# INFO:tensorflow:loss = 0.57423943, step = 46800 (30.613 sec)
# I0904 11:17:04.025718 140579447977856 basic_session_run_hooks.py:260] loss = 0.57423943, step = 46800 (30.613 sec)
# INFO:tensorflow:global_step/sec: 3.2583
# I0904 11:17:34.715561 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.2583
# INFO:tensorflow:loss = 0.24096125, step = 46900 (30.691 sec)
# I0904 11:17:34.716979 140579447977856 basic_session_run_hooks.py:260] loss = 0.24096125, step = 46900 (30.691 sec)
# INFO:tensorflow:global_step/sec: 3.27162
# I0904 11:18:05.281505 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.27162
# INFO:tensorflow:loss = 0.5653559, step = 47000 (30.566 sec)
# I0904 11:18:05.283186 140579447977856 basic_session_run_hooks.py:260] loss = 0.5653559, step = 47000 (30.566 sec)
# INFO:tensorflow:global_step/sec: 3.28652
# I0904 11:18:35.708792 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28652
# INFO:tensorflow:loss = 0.23033366, step = 47100 (30.427 sec)
# I0904 11:18:35.709983 140579447977856 basic_session_run_hooks.py:260] loss = 0.23033366, step = 47100 (30.427 sec)
# INFO:tensorflow:global_step/sec: 3.29905
# I0904 11:19:06.020519 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29905
# INFO:tensorflow:loss = 0.0962946, step = 47200 (30.312 sec)
# I0904 11:19:06.021771 140579447977856 basic_session_run_hooks.py:260] loss = 0.0962946, step = 47200 (30.312 sec)
# INFO:tensorflow:global_step/sec: 3.29147
# I0904 11:19:36.402085 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.29147
# INFO:tensorflow:loss = 0.15163459, step = 47300 (30.381 sec)
# I0904 11:19:36.403191 140579447977856 basic_session_run_hooks.py:260] loss = 0.15163459, step = 47300 (30.381 sec)
# INFO:tensorflow:global_step/sec: 3.25325
# I0904 11:20:07.140686 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.25325
# INFO:tensorflow:loss = 0.514723, step = 47400 (30.739 sec)
# I0904 11:20:07.142089 140579447977856 basic_session_run_hooks.py:260] loss = 0.514723, step = 47400 (30.739 sec)
# INFO:tensorflow:global_step/sec: 3.26678
# I0904 11:20:37.751780 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.26678
# INFO:tensorflow:loss = 1.341717, step = 47500 (30.612 sec)
# I0904 11:20:37.753617 140579447977856 basic_session_run_hooks.py:260] loss = 1.341717, step = 47500 (30.612 sec)
# INFO:tensorflow:global_step/sec: 3.28705
# I0904 11:21:08.174230 140579447977856 basic_session_run_hooks.py:692] global_step/sec: 3.28705
# INFO:tensorflow:loss = 1.2083138, step = 47600 (30.422 sec)
# I0904 11:21:08.175428 140579447977856 basic_session_run_hooks.py:260] loss = 1.2083138, step = 47600 (30.422 sec)
# INFO:tensorflow:Saving checkpoints for 47616 into training/model.ckpt.
# I0904 11:21:12.690903 140579447977856 basic_session_run_hooks.py:606] Saving checkpoints for 47616 into training/model.ckpt.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fda692363c8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0904 11:21:13.767258 140579447977856 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fda692363c8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda6716c8c8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0904 11:21:14.018772 140579447977856 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda6716c8c8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0904 11:21:14.694037 140579447977856 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:21:16.459256 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:21:16.630961 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0904 11:21:16.631384 140579447977856 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:21:17.884881 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 11:21:17.913091 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I0904 11:21:20.237286 140579447977856 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-04T11:21:20Z
# I0904 11:21:20.258069 140579447977856 evaluation.py:255] Starting evaluation at 2020-09-04T11:21:20Z
# INFO:tensorflow:Graph was finalized.
# I0904 11:21:20.828888 140579447977856 monitored_session.py:240] Graph was finalized.
# ...
# W0904 16:00:55.680372 140579447977856 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7fda685dad90> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0904 16:00:56.338848 140579447977856 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:00:58.192900 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:00:58.370289 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0904 16:00:58.370909 140579447977856 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:00:59.661240 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:00:59.681171 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I0904 16:01:01.863922 140579447977856 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-04T16:01:01Z
# I0904 16:01:01.883824 140579447977856 evaluation.py:255] Starting evaluation at 2020-09-04T16:01:01Z
# INFO:tensorflow:Graph was finalized.
# I0904 16:01:02.442025 140579447977856 monitored_session.py:240] Graph was finalized.
# 2020-09-04 16:01:02.442904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:02.443330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-09-04 16:01:02.443417: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-04 16:01:02.443459: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-09-04 16:01:02.443511: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-09-04 16:01:02.443577: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-09-04 16:01:02.443628: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-09-04 16:01:02.443666: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-09-04 16:01:02.443704: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-04 16:01:02.443834: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:02.444278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:02.444665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-04 16:01:02.444719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-04 16:01:02.444740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-04 16:01:02.444759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-04 16:01:02.444929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:02.445392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:02.445785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-100000
# I0904 16:01:02.447006 140579447977856 saver.py:1284] Restoring parameters from training/model.ckpt-100000
# INFO:tensorflow:Running local_init_op.
# I0904 16:01:03.516003 140579447977856 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0904 16:01:03.702345 140579447977856 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 103 images.
# I0904 16:01:23.290363 140576137803520 coco_evaluation.py:282] Performing evaluation on 103 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0904 16:01:23.291176 140576137803520 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I0904 16:01:23.319670 140576137803520 coco_tools.py:138] DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.04s).
# Accumulating evaluation results...
# DONE (t=0.26s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.538
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.423
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.538
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.740
# INFO:tensorflow:Finished evaluation at 2020-09-04-16:01:25
# I0904 16:01:25.781888 140579447977856 evaluation.py:275] Finished evaluation at 2020-09-04-16:01:25
# INFO:tensorflow:Saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.27219293, DetectionBoxes_Precision/mAP (large) = 0.73540175, DetectionBoxes_Precision/mAP (medium) = 0.38288078, DetectionBoxes_Precision/mAP (small) = 0.15370479, DetectionBoxes_Precision/mAP@.50IOU = 0.5382847, DetectionBoxes_Precision/mAP@.75IOU = 0.25322884, DetectionBoxes_Recall/AR@1 = 0.22300075, DetectionBoxes_Recall/AR@10 = 0.36578116, DetectionBoxes_Recall/AR@100 = 0.42320395, DetectionBoxes_Recall/AR@100 (large) = 0.74, DetectionBoxes_Recall/AR@100 (medium) = 0.5382353, DetectionBoxes_Recall/AR@100 (small) = 0.31817567, Loss/BoxClassifierLoss/classification_loss = 0.13424006, Loss/BoxClassifierLoss/localization_loss = 0.14184958, Loss/RPNLoss/localization_loss = 0.073578544, Loss/RPNLoss/objectness_loss = 0.0544188, Loss/total_loss = 0.40408704, global_step = 100000, learning_rate = 0.0002, loss = 0.40408704
# I0904 16:01:25.782272 140579447977856 estimator.py:2049] Saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.27219293, DetectionBoxes_Precision/mAP (large) = 0.73540175, DetectionBoxes_Precision/mAP (medium) = 0.38288078, DetectionBoxes_Precision/mAP (small) = 0.15370479, DetectionBoxes_Precision/mAP@.50IOU = 0.5382847, DetectionBoxes_Precision/mAP@.75IOU = 0.25322884, DetectionBoxes_Recall/AR@1 = 0.22300075, DetectionBoxes_Recall/AR@10 = 0.36578116, DetectionBoxes_Recall/AR@100 = 0.42320395, DetectionBoxes_Recall/AR@100 (large) = 0.74, DetectionBoxes_Recall/AR@100 (medium) = 0.5382353, DetectionBoxes_Recall/AR@100 (small) = 0.31817567, Loss/BoxClassifierLoss/classification_loss = 0.13424006, Loss/BoxClassifierLoss/localization_loss = 0.14184958, Loss/RPNLoss/localization_loss = 0.073578544, Loss/RPNLoss/objectness_loss = 0.0544188, Loss/total_loss = 0.40408704, global_step = 100000, learning_rate = 0.0002, loss = 0.40408704
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: training/model.ckpt-100000
# I0904 16:01:25.785791 140579447977856 estimator.py:2109] Saving 'checkpoint_path' summary for global step 100000: training/model.ckpt-100000
# INFO:tensorflow:Performing the final export in the end of training.
# I0904 16:01:25.786505 140579447977856 exporter.py:410] Performing the final export in the end of training.
# INFO:tensorflow:Calling model_fn.
# I0904 16:01:26.150179 140579447977856 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:01:27.768049 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:01:27.940334 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0904 16:01:27.940813 140579447977856 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:01:29.131939 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0904 16:01:29.151583 140579447977856 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I0904 16:01:30.124439 140579447977856 estimator.py:1150] Done calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0904 16:01:30.124781 140579447977856 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0904 16:01:30.125636 140579447977856 export_utils.py:170] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0904 16:01:30.125854 140579447977856 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# I0904 16:01:30.126038 140579447977856 export_utils.py:170] Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0904 16:01:30.126217 140579447977856 export_utils.py:170] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0904 16:01:30.126340 140579447977856 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# 2020-09-04 16:01:30.126966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:30.127388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-09-04 16:01:30.127478: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-04 16:01:30.127529: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-09-04 16:01:30.127602: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-09-04 16:01:30.127643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-09-04 16:01:30.127683: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-09-04 16:01:30.127727: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-09-04 16:01:30.127772: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-04 16:01:30.127904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:30.128348: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:30.128725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-09-04 16:01:30.128779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-04 16:01:30.128802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-09-04 16:01:30.128817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-09-04 16:01:30.128969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:30.129409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-04 16:01:30.129791: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-100000
# I0904 16:01:30.132794 140579447977856 saver.py:1284] Restoring parameters from training/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# I0904 16:01:30.707465 140579447977856 builder_impl.py:665] Assets added to graph.
# INFO:tensorflow:No assets to write.
# I0904 16:01:30.707732 140579447977856 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: training/export/Servo/temp-b'1599235285'/saved_model.pb
# I0904 16:01:31.650348 140579447977856 builder_impl.py:425] SavedModel written to: training/export/Servo/temp-b'1599235285'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.2505468.
# I0904 16:01:31.874791 140579447977856 estimator.py:371] Loss for final step: 0.2505468.

# %%
## Exporting the trained inference graph

import re
import numpy as np

output_directory = './fine_tuned_model'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-51ef7db6f3af> in <module>()
#       9 lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
#      10 steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
# ---> 11 last_model = lst[steps.argmax()].replace('.meta', '')
#      12
#      13 last_model_path = os.path.join(model_dir, last_model)
#
# ValueError: attempt to get argmax of an empty sequence

# %%
## Downloading the model.pb file
import os

pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)

# %%
# !ls -alh {pb_fname}
# Out:
# -rw-r--r-- 1 root root 50M Sep  4 16:01 /content/models/research/fine_tuned_model/frozen_inference_graph.pb

# %% [markdown]
# Uploading the model.pb file to drive

# %%
## Now upload it to drive
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fname = os.path.basename(pb_fname)
# Create & upload a text file.
uploaded = drive.CreateFile({'title': fname})
uploaded.SetContentFile(pb_fname)
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1wRax4nhRa6DFTxY9nkmA3LuTnTLwfFRq

# %%
## testing on test images
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
pb_fname = "/content/drive/My Drive/frozen_inference_graph.pb"

PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  "/content/drive/My Drive/FaceMaskTestImages"

assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
print(TEST_IMAGE_PATHS)
# Out:
# ['/content/drive/My Drive/FaceMaskTestImages/img1.jpg', '/content/drive/My Drive/FaceMaskTestImages/img2.jpg', '/content/drive/My Drive/FaceMaskTestImages/img3.jpg', '/content/drive/My Drive/FaceMaskTestImages/img4.jpg']

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util
# Out:
# /content/models/research/object_detection

# %%
## Detecting the labels and bounding boxes using frozen inference graph

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    #h = int(np.array(image.getdata()).shape[0]/(3*im_width))
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict

# %%
# %matplotlib inline

# %%
## Plotting the test images along with their predicted classes and bounding boxes

for image_path in TEST_IMAGE_PATHS:
    image = Image.open(image_path)
    #print(type(image))
    #print(np.array(image.getdata()).shape)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=8)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
